# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.colors import ListedColormap
from matplotlib.patches import Patch

# Set the global font to be Times New Roman
import matplotlib as mpl
mpl.rcParams['font.family'] = 'Times New Roman'
mpl.rcParams['font.size'] = 8 
colors = sns.color_palette()
colors
# Out:
# [(0.12156862745098039, 0.4666666666666667, 0.7058823529411765),
#  (1.0, 0.4980392156862745, 0.054901960784313725),
#  (0.17254901960784313, 0.6274509803921569, 0.17254901960784313),
#  (0.8392156862745098, 0.15294117647058825, 0.1568627450980392),
#  (0.5803921568627451, 0.403921568627451, 0.7411764705882353),
#  (0.5490196078431373, 0.33725490196078434, 0.29411764705882354),
#  (0.8901960784313725, 0.4666666666666667, 0.7607843137254902),
#  (0.4980392156862745, 0.4980392156862745, 0.4980392156862745),
#  (0.7372549019607844, 0.7411764705882353, 0.13333333333333333),
#  (0.09019607843137255, 0.7450980392156863, 0.8117647058823529)]

# %% [markdown]
# ### 1. Block assignment

# %%
# Simulate some data
states = ['US', 'CA', 'MX', 'FR', 'AR', 'IT', 'ES', 'RU', 'GB', 'CN', 'JP', 'BR', 'DE', 'AU', 'IN', 'SA', 'ZA']
data = np.zeros(shape=(len(states), 20))  # 20 time periods, for example

# Create a DataFrame
df = pd.DataFrame(data, index=states)
df.loc[['DE', 'AU', 'IN', 'SA', 'ZA'], 12:] = 1

# Create a heatmap
plt.figure(figsize=(6.7, 2.5))
cmap = ListedColormap(['lightblue', colors[0]])
plt.pcolor(df, cmap=cmap, edgecolors='k', linewidths=0.5)

# Format the figure
plt.yticks(np.arange(0.5, len(df.index), 1), df.index)
plt.xticks(np.arange(0.5, len(df.columns), 1), df.columns)
plt.gca().invert_yaxis()  # to have the states on the y-axis in the same order
legend_handles = [Patch(facecolor='lightblue', edgecolor='k', label='Control'),
                  Patch(facecolor=colors[0], edgecolor='k', label='Treated')]

# Place the legend below the x-axis
plt.legend(handles=legend_handles, loc='upper center', bbox_to_anchor=(0.5, -0.1), ncol=2)
# Save the plot
plt.tight_layout()
#plt.savefig('figs/block_assignment.png', dpi=300)

# %% [markdown]
# ### 2. Staggered adoption

# %%
# Simulate some data
states = ['US', 'CA', 'MX', 'FR', 'AR', 'IT', 'ES', 'RU', 'GB', 'CN', 'JP', 'BR', 'DE', 'AU', 'IN', 'SA', 'ZA']
data = np.zeros(shape=(len(states), 20))  # 20 time periods, for example

# Create a DataFrame
df = pd.DataFrame(data, index=states)
df.loc[['DE', 'AU'], 12:] = 1
df.loc[['IN', 'SA'], 15:] = 1
df.loc[['ZA'], 18:] = 1

# Create a heatmap
plt.figure(figsize=(6.5, 2.5))
cmap = ListedColormap(['lightblue', colors[0]])
plt.pcolor(df, cmap=cmap, edgecolors='k', linewidths=0.5)

# Format the figure
plt.yticks(np.arange(0.5, len(df.index), 1), df.index)
plt.xticks(np.arange(0.5, len(df.columns), 1), df.columns)
plt.gca().invert_yaxis()  # to have the states on the y-axis in the same order
legend_handles = [Patch(facecolor='lightblue', edgecolor='k', label='Control'),
                  Patch(facecolor=colors[0], edgecolor='k', label='Treated')]

# Place the legend below the x-axis
plt.legend(handles=legend_handles, loc='upper center', bbox_to_anchor=(0.5, -0.1), ncol=2)
# Save the plot
plt.tight_layout()
#plt.savefig('figs/staggered_adoption.png', dpi=300)

# %% [markdown]
# ### 3. Random assignment

# %%
# Simulate some data
states = ['US', 'CA', 'MX', 'FR', 'AR', 'IT', 'ES', 'RU', 'GB', 'CN', 'JP', 'BR', 'DE', 'AU', 'IN', 'SA', 'ZA']
data = np.random.binomial(1, 0.2, size=(len(states), 20))
# Create a DataFrame
df = pd.DataFrame(data, index=states)

# Create a heatmap
plt.figure(figsize=(6.5, 2.5))
cmap = ListedColormap(['lightblue', colors[0]])
plt.pcolor(df, cmap=cmap, edgecolors='k', linewidths=0.5)

# Format the figure
plt.yticks(np.arange(0.5, len(df.index), 1), df.index)
plt.xticks(np.arange(0.5, len(df.columns), 1), df.columns)
plt.gca().invert_yaxis()  # to have the states on the y-axis in the same order
legend_handles = [Patch(facecolor='lightblue', edgecolor='k', label='Control'),
                  Patch(facecolor=colors[0], edgecolor='k', label='Treated')]

# Place the legend below the x-axis
plt.legend(handles=legend_handles, loc='upper center', bbox_to_anchor=(0.5, -0.1), ncol=2)
# Save the plot
plt.tight_layout()
#plt.savefig('figs/random_assignment.png', dpi=300)
